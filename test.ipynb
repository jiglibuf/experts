# %%
import pandas as pd

# %%
register_data = pd.read_excel(r'данные\06-08 Журнал регистрации Разъяснений.xlsx', header=1)
# data = pd.read_excel('данные\Расчеты\ЗП НЗ_ЗП ЖЗ_ЗП ОНС.xlsx', dtype= object ,decimal=',', header=0)

# %%
# data[['Накопленный износ','УПКС 2023','Внешнее устаревание']].head()
register_data.head()
# Out:
#    № п/п                                       Наименование  \
# 0      1  Разъяснения, связанные с определением кадастро...
# 1      2  Разъяснения, связанные с определением кадастро...
# 2      3  Разъяснения, связанные с определением кадастро...
# 3      4  Разъяснения, связанные с определением кадастро...
# 4      5  Разъяснения, связанные с определением кадастро...
#
#      Номер разъяснения Дата разъяснения   Кадастровый номер  \
# 0  № РЗ-41/2024/000001       2024-01-11   41:01:0010119:526
# 1  № РЗ-41/2024/000002       2024-01-16   41:00:0000000:150
# 2  № РЗ-41/2024/000003       2024-01-16   41:01:0010124:352
# 3  № РЗ-41/2024/000004       2024-01-11  41:01:0010113:3194
# 4  № РЗ-41/2024/000005       2024-01-16  41:01:0010120:2163
#
#   Вид объекта недвижимости Назначение объекта недвижимости/категория земель  \
# 0                       НЗ                      Торговый комплекс "Автомир"
# 1                       ЗУ                                              ЗНП
# 2                       НЗ                                             торг
# 3                       НЗ                                        Автоцентр
# 4                       НП             НП в Административно-бытовом корпусе
#
#                             Ссылка на папку хранения Входящий номер  \
# 0     ..\..\2023\РАЗЪЯСНЕНИЯ\02-26-503 от 15.12.2023      02-26/503
# 1                             ..\..\2023\РАЗЪЯСНЕНИЯ      02-26/506
# 2     ..\..\2023\РАЗЪЯСНЕНИЯ\02-26-511 от 20.12.2023      02-26/511
# 3  ..\..\2023\РАЗЪЯСНЕНИЯ\02-26-501 от 13.12.2023...      02-26/501
# 4     ..\..\2023\РАЗЪЯСНЕНИЯ\02-26-509 от 19.12.2023      02-26/509
#
#   Дата поступления обращения
# 0                 2023-12-15
# 1                 2023-12-18
# 2                 2023-12-20
# 3                 2023-12-13
# 4                 2023-12-19
